# %%
import pickle
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pickle.load(open("./new_data/song_list_v7_without_genre_embeds.pkl","rb"))

# %%
df.head()
# Out:
#                    songid  availability  year by_decade_and_quinquennial  \
# 0  5PS5dpaLogPzYU9hWiWyZb           1.0  2006                  2005-2010
# 1  41RpZW2lxAdnqDd2nMBzLQ           1.0  2009                  2005-2010
# 2  3GsS8jzoixpCnp4jDWCEvb           1.0  1993                      90-95
# 3  0kq75szR7uDEYrZkT2c4Ry           1.0  2018                  2015-2019
# 4  2HyFpkX9J7vv3OZNDaraHZ           1.0  2005                  2005-2010
#
#    index popularity  acousticness            artist  danceability  \
# 0      0          0      0.001300  Karkkiautomaatti         0.487
# 1      1         15      0.000045    Hudson Mohawke         0.662
# 2      2         17      0.002760        Kris Kross         0.859
# 3      3         21      0.348000     Jorge Negrete         0.361
# 4      4          1      0.340000         Tiger Lou         0.533
#
#    duration_ms  ...   key  liveness  loudness  mode  speechiness    tempo  \
# ...

# %%
df.columns
# Out:
# Index(['songid', 'availability', 'year', 'by_decade_and_quinquennial', 'index',
#        'popularity', 'acousticness', 'artist', 'danceability', 'duration_ms',
#        'energy', 'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
#        'speechiness', 'tempo', 'time_signature', 'track', 'valence', 'genres'],
#       dtype='object')

# %%
df.describe().columns
# Out:
# Index(['availability', 'year', 'index', 'acousticness', 'danceability',
#        'duration_ms', 'energy', 'instrumentalness', 'key', 'liveness',
#        'loudness', 'mode', 'speechiness', 'tempo', 'time_signature',
#        'valence'],
#       dtype='object')

# %%
df["popularity"].value_counts()
# Out:
# 0      97032
# 1      43953
# 2      31507
# 3      25571
# 4      22805
#        ...
# 89         2
# NaN        2
# 87         1
# 97         1
# 94         1
# Name: popularity, Length: 92, dtype: int64

# %%
df[df.describe().columns].iloc[0].drop(["availability","year","index","duration_ms"])
# Out:
# acousticness          0.0013
# danceability          0.4870
# energy                0.6780
# instrumentalness      0.0551
# key                   9.0000
# liveness              0.0846
# loudness             -7.7800
# mode                  1.0000
# speechiness           0.0495
# tempo               149.9400
# time_signature        4.0000
# valence               0.8700
# Name: 0, dtype: float64

# %%
fig = plt.figure(figsize = (15,20))
ax = fig.gca()
df.hist(ax=ax)
# Out:
# /Users/purgatorid/.local/share/virtualenvs/data_collection-ZYhB758k/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   This is separate from the ipykernel package so we can avoid doing imports until
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11c532b10>,
# ...
#       dtype=object)

# %%
# Default Values

instrumentalness = .2

valance = .5

tempo = 120

speechiness = 0

mode = 1

loudness = -10

liveness = .22

key = 0 

energy = .6

danceability = .5

acousticness = .32

time_signature = 4

popularity = 0

# %% [markdown]
# #### Remove: Loudness, speechiness, time_signature
